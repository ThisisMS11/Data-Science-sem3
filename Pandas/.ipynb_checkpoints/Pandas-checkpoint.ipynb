# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['Mohit','Piyush','Aman','Abhishek'],
    "marks":[100,45,78,95],
    "city":['bhilwara','jaipur','Ajmer','Kolkata']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#        name  marks      city
# 0     Mohit    100  bhilwara
# 1    Piyush     45    jaipur
# 2      Aman     78     Ajmer
# 3  Abhishek     95   Kolkata

# %% [markdown]
# # Conversion into CSV File

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends without index', index=False)  # if we do not want the index to be a part of csv file

# %%
df.head(2)  # returns the top two rows
# Out:
#      name  marks      city
# 0   Mohit    100  bhilwara
# 1  Piyush     45    jaipur

# %%
df.tail(2)  #returns the bottom two rows
# Out:
#        name  marks     city
# 2      Aman     78    Ajmer
# 3  Abhishek     95  Kolkata

# %%
df
# Out:
#        name  marks      city
# 0     Mohit    100  bhilwara
# 1    Piyush     45    jaipur
# 2      Aman     78     Ajmer
# 3  Abhishek     95   Kolkata

# %%
df.describe()  # describes all the stats related to our csv
# Out:
#             marks
# count    4.000000
# mean    79.500000
# std     24.852901
# min     45.000000
# 25%     69.750000
# 50%     86.500000
# 75%     96.250000
# max    100.000000

# %%
newcsv=pd.read_csv('friends2.csv')     # to read external CSV files

# %%
newcsv
# Out:
#        name  percentage      city
# 0     Mohit         100  bhilwara
# 1    Piyush          45    jaipur
# 2      Aman          78     Ajmer
# 3  Abhishek          95   Kolkata

# %%
newcsv['city']         # will return only the city column of our csv file
# Out:
# 0    bhilwara
# 1      jaipur
# 2       Ajmer
# 3     Kolkata
# Name: city, dtype: object

# %%
newcsv['percentage'][0]='101'   # we can change the values of our csv like this
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3228\946242224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newcsv['percentage'][0]='101'   # we can change the values of our csv like this

# %%
newcsv
# Out:
#        name percentage      city
# 0     Mohit        101  bhilwara
# 1    Piyush         45    jaipur
# 2      Aman         78     Ajmer
# 3  Abhishek         95   Kolkata

# %%
newcsv.to_csv('friends.csv')

# %%
newcsv.index=['first','second','third','fourth']

# %%
newcsv
# Out:
#             name percentage      city
# first      Mohit        101  bhilwara
# second    Piyush         45    jaipur
# third       Aman         78     Ajmer
# fourth  Abhishek         95   Kolkata

# %% [markdown]
# # Data Structures in Pandas

# %% [markdown]
# ![](ds.png)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
ser=pd.Series(np.random.rand(34))  # will give a randomly generated series datastructure

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# 0     0.891929
# 1     0.764401
# 2     0.310032
# 3     0.949963
# 4     0.512760
# 5     0.892758
# 6     0.819712
# 7     0.357986
# 8     0.046429
# 9     0.039942
# 10    0.462146
# 11    0.850386
# 12    0.756352
# 13    0.908292
# 14    0.876201
# 15    0.246143
# 16    0.548928
# 17    0.893359
# 18    0.170963
# 19    0.960485
# 20    0.392561
# 21    0.538998
# 22    0.427377
# 23    0.004489
# 24    0.302522
# 25    0.251904
# 26    0.954671
# 27    0.766067
# 28    0.872042
# 29    0.829816
# 30    0.850138
# 31    0.008924
# 32    0.226065
# 33    0.559805
# dtype: float64

# %%
newdf=pd.DataFrame(np.random.rand(334,5))  # will give a randomly generated dataframe datastructure 334=columns and 5=rows

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
# 329                     0.676806  0.908054  0.152604  0.876472  0.834565
# 330                     0.933295  0.980543  0.874470  0.690798  0.063500
# 331                     0.002448  0.870904  0.361060  0.398449  0.840384
# 332                     0.084819  0.147418  0.947436  0.584819  0.769418
# 333                     0.058776  0.137820  0.743634  0.616780  0.059585
#
# [334 rows x 5 columns]

# %%
newdf3
# Out:
#                                  0         1         2         3         4
# 0    Mohit saini greatest of great  0.048022  0.841071  0.402856  0.691048
# 1                         0.821379  0.316786  0.308527  0.807493  0.886862
# 2                         0.442271  0.495471  0.076116  0.801529  0.662356
# 3                         0.733101  0.091347  0.921864  0.675040  0.932351
# 4                         0.957264  0.764690  0.552713  0.005443  0.303896
# ..                             ...       ...       ...       ...       ...
# 329                       0.676806  0.908054  0.152604  0.876472  0.834565
# 330                       0.933295  0.980543  0.874470  0.690798  0.063500
# 331                       0.002448  0.870904  0.361060  0.398449  0.840384
# 332                       0.084819  0.147418  0.947436  0.584819  0.769418
# 333                       0.058776  0.137820  0.743634  0.616780  0.059585
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0]='using loc for the first time' #

# %%
newdf
# Out:
#                                 0         1         2         3         4
# 0    using loc for the first time  0.048022  0.841071  0.402856  0.691048
# 1                        0.821379  0.316786  0.308527  0.807493  0.886862
# 2                        0.442271  0.495471  0.076116  0.801529  0.662356
# 3                        0.733101  0.091347  0.921864  0.675040  0.932351
# 4                        0.957264  0.764690  0.552713  0.005443  0.303896
# ..                            ...       ...       ...       ...       ...
# 329                      0.676806  0.908054  0.152604  0.876472  0.834565
# 330                      0.933295  0.980543  0.874470  0.690798  0.063500
# 331                      0.002448  0.870904  0.361060  0.398449  0.840384
# 332                      0.084819  0.147418  0.947436  0.584819  0.769418
# 333                      0.058776  0.137820  0.743634  0.616780  0.059585
#
# [334 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#                               0         1         2         3         4
# 0  using loc for the first time  0.048022  0.841071  0.402856  0.691048
# 1                      0.821379  0.316786  0.308527  0.807493  0.886862

# %%
newdf.columns=list('ABCDE') # this will change the columns indices from [0,5] to [A,B]

# %% [markdown]
# ## to drop a specific row or columns using index

# %%
newdf.drop(0,axis=0)
# Out:
#             A         B         C         D         E
# 1    0.821379  0.316786  0.308527  0.807493  0.886862
# 2    0.442271  0.495471  0.076116  0.801529  0.662356
# 3    0.733101  0.091347  0.921864  0.675040  0.932351
# 4    0.957264  0.764690  0.552713  0.005443  0.303896
# 5    0.950808  0.955393  0.230742  0.879771  0.827253
# ..        ...       ...       ...       ...       ...
# 329  0.676806  0.908054  0.152604  0.876472  0.834565
# 330  0.933295  0.980543  0.874470  0.690798  0.063500
# 331  0.002448  0.870904  0.361060  0.398449  0.840384
# 332  0.084819  0.147418  0.947436  0.584819  0.769418
# 333  0.058776  0.137820  0.743634  0.616780  0.059585
#
# [333 rows x 5 columns]

# %%
newdf.loc[[1,2],['A','D']]   # to get specific data from our csv
# Out:
#           A         D
# 1  0.821379  0.807493
# 2  0.442271  0.801529

# %%
newdf.loc[:,['A','E']] # use ':'  to get all the rows or columns
# Out:
#                                 A         E
# 0    using loc for the first time  0.691048
# 1                        0.821379  0.886862
# 2                        0.442271  0.662356
# 3                        0.733101  0.932351
# 4                        0.957264  0.303896
# ..                            ...       ...
# 329                      0.676806  0.834565
# 330                      0.933295  0.063500
# 331                      0.002448  0.840384
# 332                      0.084819  0.769418
# 333                      0.058776  0.059585
#
# [334 rows x 2 columns]

# %%
newdf
# Out:
#                                 A         B         C         D         E
# 0    using loc for the first time  0.048022  0.841071  0.402856  0.691048
# 1                        0.821379  0.316786  0.308527  0.807493  0.886862
# 2                        0.442271  0.495471  0.076116  0.801529  0.662356
# 3                        0.733101  0.091347  0.921864  0.675040  0.932351
# 4                        0.957264  0.764690  0.552713  0.005443  0.303896
# ..                            ...       ...       ...       ...       ...
# 329                      0.676806  0.908054  0.152604  0.876472  0.834565
# 330                      0.933295  0.980543  0.874470  0.690798  0.063500
# 331                      0.002448  0.870904  0.361060  0.398449  0.840384
# 332                      0.084819  0.147418  0.947436  0.584819  0.769418
# 333                      0.058776  0.137820  0.743634  0.616780  0.059585
#
# [334 rows x 5 columns]

# %%
newdf.loc[(newdf['B'] < 0.12) & (newdf['C'] > 0.5)].head()           # Searching data based on sum filter.
# Out:
#                                A         B         C         D         E
# 0   using loc for the first time  0.048022  0.841071  0.402856  0.691048
# 3                       0.733101  0.091347  0.921864  0.675040  0.932351
# 26                      0.649633  0.115303  0.648238  0.422085  0.943800
# 78                      0.531638  0.067785  0.587497  0.231251  0.873986
# 85                      0.572686  0.103415  0.875591  0.655133  0.788938

# %%
newdf.iloc[0,4]    # 4 positions left to index 0
# Out:
# 0.6910477091580167

# %%
newdf.iloc[[0,1],[1,2]]   # o and1 rows and (1= B & 2= C)
# Out:
#           B         C
# 0  0.048022  0.841071
# 1  0.316786  0.308527

# %% [markdown]
# ## Droping a Column

# %%
newdf.drop(['A','C'], axis=1)  # to drop the column with A and C along the horizontal axis in the copy of newdf
# Out:
#             B         D         E
# 0    0.048022  0.402856  0.691048
# 1    0.316786  0.807493  0.886862
# 2    0.495471  0.801529  0.662356
# 3    0.091347  0.675040  0.932351
# 4    0.764690  0.005443  0.303896
# ..        ...       ...       ...
# 329  0.908054  0.876472  0.834565
# 330  0.980543  0.690798  0.063500
# 331  0.870904  0.398449  0.840384
# 332  0.147418  0.584819  0.769418
# 333  0.137820  0.616780  0.059585
#
# [334 rows x 3 columns]

# %%
newdf.drop(['A','C'], axis=1,inplace=True) # will change the original newdf

# %%
newdf.drop([1,5], axis=0,inplace=True) # will drop the row with indices 1 and 5 in the original newdf

# %%
newdf
# Out:
#             B         D         E
# 0    0.048022  0.402856  0.691048
# 2    0.495471  0.801529  0.662356
# 3    0.091347  0.675040  0.932351
# 4    0.764690  0.005443  0.303896
# 6    0.393307  0.344465  0.643865
# ..        ...       ...       ...
# 329  0.908054  0.876472  0.834565
# 330  0.980543  0.690798  0.063500
# 331  0.870904  0.398449  0.840384
# 332  0.147418  0.584819  0.769418
# 333  0.137820  0.616780  0.059585
#
# [332 rows x 3 columns]

# %%
newdf.reset_index()        # to reset all the indices after the removal of certain but it adds a additiona index column so to drop that additional column we can do one drop=True in our main statement
# Out:
#      index         B         D         E
# 0        0  0.048022  0.402856  0.691048
# 1        2  0.495471  0.801529  0.662356
# 2        3  0.091347  0.675040  0.932351
# 3        4  0.764690  0.005443  0.303896
# 4        6  0.393307  0.344465  0.643865
# ..     ...       ...       ...       ...
# 327    329  0.908054  0.876472  0.834565
# 328    330  0.980543  0.690798  0.063500
# 329    331  0.870904  0.398449  0.840384
# 330    332  0.147418  0.584819  0.769418
# 331    333  0.137820  0.616780  0.059585
#
# [332 rows x 4 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             B         D         E
# 0    0.048022  0.402856  0.691048
# 1    0.495471  0.801529  0.662356
# 2    0.091347  0.675040  0.932351
# 3    0.764690  0.005443  0.303896
# 4    0.393307  0.344465  0.643865
# ..        ...       ...       ...
# 327  0.908054  0.876472  0.834565
# 328  0.980543  0.690798  0.063500
# 329  0.870904  0.398449  0.840384
# 330  0.147418  0.584819  0.769418
# 331  0.137820  0.616780  0.059585
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()  # returns false where values are not null
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 6      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 332, dtype: bool

# %%
#newdf.['B']=None
# but it is prefered to use loc instead of doing it directly
newdf.loc[:,['B']]=None

# %%
newdf.isnull()
# Out:
#         B      D      E
# 0    True  False  False
# 2    True  False  False
# 3    True  False  False
# 4    True  False  False
# 6    True  False  False
# ..    ...    ...    ...
# 329  True  False  False
# 330  True  False  False
# 331  True  False  False
# 332  True  False  False
# 333  True  False  False
#
# [332 rows x 3 columns]

# %% [markdown]
# ## To drop a null values

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df.dropna(axis=1) # dropna drops the entire corresponding rows or columns wherever it founds any null value.
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(axis=1,how='all')

#how attribute
#‘any’ : If any NA values are present, drop that row or column.
#‘all’ : If all values are NA, drop that row or column.
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df2=pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df2
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df2.dropna(axis=1,how='all') # will drop that column where all the corresponding values will be found NaN
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df3=pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %% [markdown]
# ## Removing Duplicates
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html?highlight=drop_duplicates#pandas.DataFrame.drop_duplicates

# %%
df3
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25
# 2  Alfred  NaN        NaT

# %%
df3.drop_duplicates()
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25

# %%
df3.drop_duplicates(subset=['name'],keep=False)  # False : Drop all duplicates.
# Out:
#      name  toy       born
# 1  Batman  NaN 1940-04-25

# %% [markdown]
# continue....56:58 / 1:05:23

# %%
df3.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df['toy'].value_counts(dropna=False) # google it
# Out:
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %% [markdown]
# ![](hw.png)

# %%
data=pd.read_excel('HW.xlsx')

# %%
data
# Out:
#      S. No.             Name    Mobile No.  WhatsApp No.
# 0         1      Poonam Soni  9.636266e+09           NaN
# 1         2  Bhavika Agarwal  9.829194e+09           NaN
# 2         3        Disha Sen  9.602761e+09           NaN
# 3         4     Prateek Jain  8.946836e+09           NaN
# 4         5     Pankaj Gupta  8.764483e+09           NaN
# ..      ...              ...           ...           ...
# 383     384              NaN           NaN           NaN
# 384     385              NaN           NaN           NaN
# 385     386              NaN           NaN           NaN
# 386     387              NaN           NaN           NaN
# 387     388              NaN           NaN           NaN
#
# [388 rows x 4 columns]

# %%
data.drop(['WhatsApp No.'],axis=1, inplace=True)

# %%
data.head()
# Out:
#    S. No.             Name    Mobile No.
# 0       1      Poonam Soni  9.636266e+09
# 1       2  Bhavika Agarwal  9.829194e+09
# 2       3        Disha Sen  9.602761e+09
# 3       4     Prateek Jain  8.946836e+09
# 4       5     Pankaj Gupta  8.764483e+09
