# %%
# %matplotlib inline
import matplotlib as mp
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[2,5,7])   #(x1,x2,x3) (y1,y2,y3)
plt.show()

# %%
# plt.title=("Mohit siani") not working 
plt.xlabel("This is X")
plt.ylabel("This is Y")
plt.show()

# %% [markdown]
# # Comparing two line graphs

# %%
x=[1,5,9]
y=[23,45,89]
x2=[3,7,10]
y2=[38,50,100]

# %%
plt.plot(x,y,color='red',label='Mohit')
plt.plot(x2,y2,color='black',label="Aman")
plt.legend()
plt.show()

# %%
x=[1,5,9]
y=[23,45,89]
x2=[3,7,10]
y2=[38,50,100]

# %%
plt.scatter(x,y,label='first',linewidth=3,color='green')
